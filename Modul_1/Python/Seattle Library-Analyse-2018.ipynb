# %%
import urllib.request
import pandas as pd

# %%
url = "https://data.seattle.gov/resource/tmmm-ytt6.csv?$where=checkoutyear=2018&$limit=10000"
checkout_file = "checkout.csv"
urllib.request.urlretrieve(url, checkout_file)
# Out:
# ('checkout.csv', <http.client.HTTPMessage at 0x7fd3bf1bc070>)

# %%
#in einen DataFrame laden
checkout_df = pd.read_csv(checkout_file)

# %%
#show table
checkout_df
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2018             12
# 1      Physical      Horizon         BOOK          2018             12
# 2      Physical      Horizon    VIDEODISC          2018             12
# 3       Digital    OverDrive    AUDIOBOOK          2018             12
# 4      Physical      Horizon         BOOK          2018             12
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon    SOUNDDISC          2018             12
# 9996   Physical      Horizon    VIDEODISC          2018             12
# 9997   Physical      Horizon         BOOK          2018             12
# 9998   Physical      Horizon    VIDEODISC          2018             12
# 9999   Physical      Horizon         BOOK          2018             12
#
#       checkouts                                              title  \
# ...

# %%
checkout_df.shape
# Out:
# (10000, 11)

# %%
checkout_df.head
# Out:
# <bound method NDFrame.head of      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 0      Physical      Horizon         BOOK          2018             12
# 1      Physical      Horizon         BOOK          2018             12
# 2      Physical      Horizon    VIDEODISC          2018             12
# 3       Digital    OverDrive    AUDIOBOOK          2018             12
# 4      Physical      Horizon         BOOK          2018             12
# ...         ...          ...          ...           ...            ...
# 9995   Physical      Horizon    SOUNDDISC          2018             12
# 9996   Physical      Horizon    VIDEODISC          2018             12
# 9997   Physical      Horizon         BOOK          2018             12
# 9998   Physical      Horizon    VIDEODISC          2018             12
# 9999   Physical      Horizon         BOOK          2018             12
#
#       checkouts                                              title  \
# ...

# %%
checkout_df.columns
# Out:
# Index(['usageclass', 'checkouttype', 'materialtype', 'checkoutyear',
#        'checkoutmonth', 'checkouts', 'title', 'creator', 'subjects',
#        'publisher', 'publicationyear'],
#       dtype='object')

# %%
checkout_df["subjects"].unique()
# Out:
# array(['Naruto Fictitious character Comic books strips etc, Ninja Japan Comic books strips etc, Graphic novels',
#        'Polar bear Juvenile fiction, Food Juvenile fiction, Picture books for children, Japanese language materials',
#        'First loves Drama, College students Drama, Feature films, Fiction films, Video recordings for the hearing impaired, Video recordings for people with visual disabilities',
#        ..., 'Folklore China, Honesty Juvenile literature, Picture books',
#        'Marshalsea Prison Southwark London England Drama, Social classes England Drama, Women dressmakers England Drama, England Social conditions 19th century Drama, London England Drama, Television mini series, Fiction television programs, Video recordings for the hearing impaired',
#        'Fairy tales, Magic Fiction, Rats Juvenile fiction'], dtype=object)

# %%
checkout_df["materialtype"].unique()
# Out:
# array(['BOOK', 'VIDEODISC', 'AUDIOBOOK', 'EBOOK', 'SOUNDDISC', 'MUSIC',
#        'CR', 'VIDEO', 'SOUNDREC', 'REGPRINT', 'LARGEPRINT',
#        'SOUNDDISC, VIDEODISC', 'ER', 'MAGAZINE', 'MIXED', 'ER, SOUNDDISC'],
#       dtype=object)

# %%
checkout_df[checkout_df["materialtype"] == "EBOOK"]
# Out:
#      usageclass checkouttype materialtype  checkoutyear  checkoutmonth  \
# 7       Digital    OverDrive        EBOOK          2018             12
# 17      Digital    OverDrive        EBOOK          2018             12
# 21      Digital    OverDrive        EBOOK          2018             12
# 23      Digital    OverDrive        EBOOK          2018             12
# 26      Digital    OverDrive        EBOOK          2018             12
# ...         ...          ...          ...           ...            ...
# 9975    Digital    OverDrive        EBOOK          2018             12
# 9980    Digital    OverDrive        EBOOK          2018             12
# 9986    Digital    OverDrive        EBOOK          2018             12
# 9988    Digital    OverDrive        EBOOK          2018             12
# 9991    Digital    OverDrive        EBOOK          2018             12
#
#       checkouts                                              title  \
# ...

# %%
checkout_df.describe()
# Out:
#        checkoutyear  checkoutmonth     checkouts
# count       10000.0        10000.0  10000.000000
# mean         2018.0           12.0      3.478300
# std             0.0            0.0     10.473533
# min          2018.0           12.0      1.000000
# 25%          2018.0           12.0      1.000000
# 50%          2018.0           12.0      2.000000
# 75%          2018.0           12.0      3.000000
# max          2018.0           12.0    585.000000

# %%
checkout_df.sum()
# Out:
# usageclass       PhysicalPhysicalPhysicalDigitalPhysicalPhysica...
# checkouttype     HorizonHorizonHorizonOverDriveHorizonHorizonHo...
# materialtype     BOOKBOOKVIDEODISCAUDIOBOOKBOOKBOOKBOOKEBOOKVID...
# checkoutyear                                              20180000
# checkoutmonth                                               120000
# checkouts                                                    34783
# title            Naruto. Vol. 65, Hashirama and Madara / story ...
# dtype: object

# %%
checkout_df["materialtype"].value_counts()
# Out:
# BOOK                    4573
# EBOOK                   2535
# AUDIOBOOK               1035
# SOUNDDISC                888
# VIDEODISC                874
# MUSIC                     27
# REGPRINT                  18
# SOUNDDISC, VIDEODISC      13
# MAGAZINE                   6
# VIDEO                      6
# CR                         6
# ER                         6
# SOUNDREC                   5
# LARGEPRINT                 4
# ER, SOUNDDISC              2
# MIXED                      2
# Name: materialtype, dtype: int64

# %%
checkout_df["materialtype"].values
# Out:
# array(['BOOK', 'BOOK', 'VIDEODISC', ..., 'BOOK', 'VIDEODISC', 'BOOK'],
#       dtype=object)
