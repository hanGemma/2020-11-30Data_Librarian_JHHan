# %%
import os
import pandas as pd
 
dir = os.getcwd().replace("notebook","")
#print(dir+os.path.sep+"data"+os.path.sep)
pd.read_csv(dir+os.path.sep+"data"+os.path.sep+"Library_Usage.csv")
#output  423448 rows × 15 columns: 423448 Datensätze, 15 Merkmale
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df = pd.read_csv(dir+os.path.sep+"data"+os.path.sep+"Library_Usage.csv")
type(df)
#data taye :pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423448 entries, 0 to 423447
# Data columns (total 15 columns):
# Patron Type Code                423448 non-null int64
# Patron Type Definition          423448 non-null object
# Total Checkouts                 423448 non-null int64
# Total Renewals                  423448 non-null int64
# Age Range                       423233 non-null object
# Home Library Code               423408 non-null object
# Home Library Definition         423448 non-null object
# Circulation Active Month        423448 non-null object
# Circulation Active Year         423448 non-null object
# Notice Preference Code          423448 non-null object
# Notice Preference Definition    423448 non-null object
# Provided Email Address          423448 non-null bool
# Year Patron Registered          423448 non-null int64
# Outside of County               423448 non-null bool
# Supervisor District             313138 non-null float64
# ...

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
dfbyYear= data.sort_values(by='Circulation Active Year')
dfbyYear[1:2]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 151205                 0                  ADULT                7
#
#         Total Renewals       Age Range Home Library Code  \
# 151205               9  35 to 44 years                 X
#
#        Home Library Definition Circulation Active Month  \
# 151205            Main Library                 December
#
#        Circulation Active Year Notice Preference Code  \
# 151205                    2003                      a
#
#        Notice Preference Definition  Provided Email Address  \
# 151205                        print                   False
#
#         Year Patron Registered  Outside of County  Supervisor District
# 151205                    2003              False                  6.0

# %%
dfbyYear[423447:]
# daten von 2003 bis 2019 aber es gibt fehlende Werte.
#Zeilen auswählen ddata[anfang index:end index+1]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 423447                 1               JUVENILE                0
#
#         Total Renewals     Age Range Home Library Code  \
# 423447               0  0 to 9 years                E7
#
#                    Home Library Definition Circulation Active Month  \
# 423447  Eureka Valley/Harvey Milk Memorial                     None
#
#        Circulation Active Year Notice Preference Code  \
# 423447                    None                      a
#
#        Notice Preference Definition  Provided Email Address  \
# 423447                        print                   False
#
#         Year Patron Registered  Outside of County  Supervisor District
# 423447                    2015              False                  8.0

# %%
#select column 
dfbyYear['Circulation Active Year']
# Out:
# 393676    2003
# 151205    2003
# 110721    2003
# 194544    2003
# 416917    2003
#           ...
# 228023    None
# 228020    None
# 228019    None
# 228089    None
# 423447    None
# Name: Circulation Active Year, Length: 423448, dtype: object

# %% [markdown]
# # 2.2 Skalenniveau und Datentypen

# %%
x= pd.Series([34,12,23,45])
print(x)
x.dtype
# Out:
# 0    34
# 1    12
# 2    23
# 3    45
# dtype: int64
# dtype('int64')

# %%
data = {'month': ['Jan', 'Feb', 'Mar'],
        'temp': [-5, 2, 3],
        'below_zero': [True, False, False]}
df2=pd.DataFrame(data)
print(df2)
df2.info()
# Out:
#   month  temp  below_zero
# 0   Jan    -5        True
# 1   Feb     2       False
# 2   Mar     3       False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# month         3 non-null object
# temp          3 non-null int64
# below_zero    3 non-null bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %% [markdown]
# # Skalenniveau
# month: norminal diskret object
#
# temp: kardinal stetig int
#
# below_zero: norminal diskret bool

# %%
df3 =pd.DataFrame([["Apr",5, False]],columns=df2.columns)
#df2.append(df3,ignore_index=True)
#print(df2.columns)
#print(df2)
#print(df3)
df2=df2.append(df3,ignore_index=True)
print(df2)
# Out:
#   month  temp  below_zero
# 0   Jan    -5        True
# 1   Feb     2       False
# 2   Mar     3       False
# 3   Apr     5       False

# %%
df4 =pd.DataFrame([2020,2020,2020,2020],columns=["year"])
df2.join(df4)
# Out:
#   month  temp  below_zero  year
# 0   Jan    -5        True  2020
# 1   Feb     2       False  2020
# 2   Mar     3       False  2020
# 3   Apr     5       False  2020

# %% [markdown]
# # 2.3 Exkurs: Datenrundreise

# %%
import os
import pandas as pd
 
dir = os.getcwd().replace("notebook","")
#print(dir+os.path.sep+"data"+os.path.sep)
dfsmall=pd.read_csv(dir+os.path.sep+"data"+os.path.sep+"Library_Usage_Small.csv")
dfsmall
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  1               JUVENILE              518               8
# 1                  1               JUVENILE               38               0
# 2                  0                  ADULT               38               4
# 3                  0                  ADULT               48              48
# 4                  1               JUVENILE               28              13
# 5                  1               JUVENILE                1               0
# 6                  1               JUVENILE              293              11
# 7                  1               JUVENILE              900               6
# 8                  1               JUVENILE             1569             801
# 9                  1               JUVENILE               45               0
# 10                 1               JUVENILE                0               0
# ...

# %%
dfsmall.to_json("../data/Library_Usage_Small.json")

# %%
pd.read_json("../data/Library_Usage_Small.json").to_html("../data/Library_Usage_Small.html")

# %%
type(pd.read_html("../data/Library_Usage_Small.html"))
htmllist = pd.read_html("../data/Library_Usage_Small.html")
htmldf=htmllist[0]
type(htmldf)

#.("../data/Library_Usage_Smallexcel.xlsx")
#htmllist
#pd.DataFrame(htmllist)
# Out:
# pandas.core.frame.DataFrame

# %%
htmldf.to_excel('../data/Library_Usage_Smallnew.xlsx', index=False)
dfnewexcel = pd.read_excel('../data/Library_Usage_Smallnew.xlsx')
dfnewexcel.to_csv('../data/Library_Usage_Smallnew.csv')
