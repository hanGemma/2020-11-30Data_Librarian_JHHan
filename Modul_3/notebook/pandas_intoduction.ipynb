# %% [markdown]
# # 2.1
# # # Wie groß ist die Stichprobengröße des Datensatzes?
# 423228.
#
# ## Wer oder was sind die Merkmalsträger?
# Bibliothekskunden der SF Public Library.
#
# ## Von wann bis wann wurden die Daten erhoben?
# 2003 - 2016
#
# ## Wie lässt sich die Grundgesamtheit beschreiben? Handelt es sich um eine Vollerhebung?
# Grundgesamtheit: alle Bibliothekskunden der San Francisco Library
#
# ## Welche Merkmale sind stetig? Welche diskret?
# stetig: Total Checkouts, Total Renewals, superviser district
# diskret: alle andere
#
# ## Welchem Skalenniveau entsprechen die einzelnen Merkmale (Nominal-, Ordinal- oder Metrische Skala)?
#
# Nominal: Patron Type Definition,Patron Type Code, Home Library Code, Home Library Definition,
#  , Notice Preference Code, Notice Preference Definition,
#  Provided Email Address,
#
# Ordinal: Age Range?  CIrculation Active Month,
#
# Metrische: Total Checkouts, Total Renewals, Circulation Active Year, Year Patron Registered, supervisor District
#
# ## Enthält der Datensatz fehlende Werte?
# ja
#
# ## Handelt es sich um Querschnitts-, Längsschnitss- oder Paneldaten?
# Querschnittsdaten.

# %%
import os
import pandas as pd
 
dir = os.getcwd().replace("notebook","")
#print(dir+os.path.sep+"data"+os.path.sep)
pd.read_csv(dir+os.path.sep+"data"+os.path.sep+"Library_Usage.csv")
#output  423448 rows × 15 columns: 423448 Datensätze, 15 Merkmale
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df = pd.read_csv(dir+os.path.sep+"data"+os.path.sep+"Library_Usage.csv")
type(df)
#data taye :pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423448 entries, 0 to 423447
# Data columns (total 15 columns):
# Patron Type Code                423448 non-null int64
# Patron Type Definition          423448 non-null object
# Total Checkouts                 423448 non-null int64
# Total Renewals                  423448 non-null int64
# Age Range                       423233 non-null object
# Home Library Code               423408 non-null object
# Home Library Definition         423448 non-null object
# Circulation Active Month        423448 non-null object
# Circulation Active Year         423448 non-null object
# Notice Preference Code          423448 non-null object
# Notice Preference Definition    423448 non-null object
# Provided Email Address          423448 non-null bool
# Year Patron Registered          423448 non-null int64
# Outside of County               423448 non-null bool
# Supervisor District             313138 non-null float64
# ...

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
df['Circulation Active Year'].unique()
# Out:
# array(['None', '2016', '2014', '2015', '2012', '2013', '2011', '2009',
#        '2010', '2007', '2006', '2008', '2005', '2004', '2003'],
#       dtype=object)

# %% [markdown]
# # 2.2 Skalenniveau und Datentypen

# %%
x= pd.Series([34,12,23,45])
print(x)
x.dtype
# Out:
# 0    34
# 1    12
# 2    23
# 3    45
# dtype: int64
# dtype('int64')

# %%
data = {'month': ['Jan', 'Feb', 'Mar'],
        'temp': [-5, 2, 3],
        'below_zero': [True, False, False]}
df2=pd.DataFrame(data)
print(df2)
df2.info()
# Out:
#   month  temp  below_zero
# 0   Jan    -5        True
# 1   Feb     2       False
# 2   Mar     3       False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
# month         3 non-null object
# temp          3 non-null int64
# below_zero    3 non-null bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %% [markdown]
# # Skalenniveau
# month: norminal diskret object
#
# temp: kardinal stetig int
#
# below_zero: norminal diskret bool

# %%
df3 =pd.DataFrame([["Apr",5, False]],columns=df2.columns)
#df2.append(df3,ignore_index=True)
#print(df2.columns)
#print(df2)
#print(df3)
df2=df2.append(df3,ignore_index=True)
print(df2)
# Out:
#   month  temp  below_zero
# 0   Jan    -5        True
# 1   Feb     2       False
# 2   Mar     3       False
# 3   Apr     5       False

# %%
df4 =pd.DataFrame([2020,2020,2020,2020],columns=["year"])
df2.join(df4)
# Out:
#   month  temp  below_zero  year
# 0   Jan    -5        True  2020
# 1   Feb     2       False  2020
# 2   Mar     3       False  2020
# 3   Apr     5       False  2020

# %% [markdown]
# # 2.3 Exkurs: Datenrundreise

# %%
import os
import pandas as pd
 
dir = os.getcwd().replace("notebook","")
#print(dir+os.path.sep+"data"+os.path.sep)
dfsmall=pd.read_csv(dir+os.path.sep+"data"+os.path.sep+"Library_Usage_Small.csv")
dfsmall
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                  1               JUVENILE              518               8
# 1                  1               JUVENILE               38               0
# 2                  0                  ADULT               38               4
# 3                  0                  ADULT               48              48
# 4                  1               JUVENILE               28              13
# 5                  1               JUVENILE                1               0
# 6                  1               JUVENILE              293              11
# 7                  1               JUVENILE              900               6
# 8                  1               JUVENILE             1569             801
# 9                  1               JUVENILE               45               0
# 10                 1               JUVENILE                0               0
# ...

# %%
dfsmall.to_json("../data/Library_Usage_Small.json")

# %%
pd.read_json("../data/Library_Usage_Small.json").to_html("../data/Library_Usage_Small.html")

# %%
type(pd.read_html("../data/Library_Usage_Small.html"))
htmllist = pd.read_html("../data/Library_Usage_Small.html")
htmldf=htmllist[0]
type(htmldf)

#.("../data/Library_Usage_Smallexcel.xlsx")
#htmllist
#pd.DataFrame(htmllist)
# Out:
# pandas.core.frame.DataFrame

# %%
htmldf.to_excel('../data/Library_Usage_Smallnew.xlsx', index=False)
dfnewexcel = pd.read_excel('../data/Library_Usage_Smallnew.xlsx')
dfnewexcel.to_csv('../data/Library_Usage_Smallnew.csv')

# %% [markdown]
# # 2.4 Exkurs: Arbeitsspeicher
# 339 GB Frei
# 339000000000 Byte / 8 = 42.375.000.000 int64 Werte

# %%
df.info(memory_usage='deep')
# df memory usage: 222.5 MB
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423448 entries, 0 to 423447
# Data columns (total 15 columns):
# Patron Type Code                423448 non-null int64
# Patron Type Definition          423448 non-null object
# Total Checkouts                 423448 non-null int64
# Total Renewals                  423448 non-null int64
# Age Range                       423233 non-null object
# Home Library Code               423408 non-null object
# Home Library Definition         423448 non-null object
# Circulation Active Month        423448 non-null object
# Circulation Active Year         423448 non-null object
# Notice Preference Code          423448 non-null object
# Notice Preference Definition    423448 non-null object
# Provided Email Address          423448 non-null bool
# Year Patron Registered          423448 non-null int64
# Outside of County               423448 non-null bool
# Supervisor District             313138 non-null float64
# ...

# %%
df.memory_usage(deep=True)
# Out:
# Index                                128
# Patron Type Code                 3387584
# Patron Type Definition          26722568
# Total Checkouts                  3387584
# Total Renewals                   3387584
# Age Range                       30022389
# Home Library Code               25359505
# Home Library Definition         28744750
# Circulation Active Month        26356718
# Circulation Active Year         25830328
# Notice Preference Code          26253764
# Notice Preference Definition    26253773
# Provided Email Address            423448
# Year Patron Registered           3387584
# Outside of County                 423448
# Supervisor District              3387584
# dtype: int64

# %% [markdown]
# # 2.5 Fallstudie: Feature Engineering

# %%
df.columns
# Out:
# Index(['Patron Type Code', 'Patron Type Definition', 'Total Checkouts',
#        'Total Renewals', 'Age Range', 'Home Library Code',
#        'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Code',
#        'Notice Preference Definition', 'Provided Email Address',
#        'Year Patron Registered', 'Outside of County', 'Supervisor District'],
#       dtype='object')

# %%
x = df["Total Renewals"]
print(type(x))
print(x)
# Out:
# <class 'pandas.core.series.Series'>
# 0          0
# 1         22
# 2          0
# 3          0
# 4         11
#           ..
# 423443    13
# 423444    11
# 423445    58
# 423446     0
# 423447     0
# Name: Total Renewals, Length: 423448, dtype: int64

# %%
# df[['Total Renewals', 'Total Checkouts']]
column_names = ['Total Renewals', 'Total Checkouts'] # auxiliary variable
subset = df[column_names]
print(subset)
type(subset)
# Out:
#         Total Renewals  Total Checkouts
# 0                    5                0
# 1                    5               31
# 2                    5                0
# 3                    5                0
# 4                    5              126
# ...                ...              ...
# 423443               5              291
# 423444               5               15
# 423445               5              208
# 423446               5               26
# 423447               5                0
#
# [423448 rows x 2 columns]
# pandas.core.frame.DataFrame

# %%
df['dummy_variable'] = 5

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
x = df['Total Renewals']
print(x)
df['Total Renewals'] = 5
x
# Out:
# 0          0
# 1         22
# 2          0
# 3          0
# 4         11
#           ..
# 423443    13
# 423444    11
# 423445    58
# 423446     0
# 423447     0
# Name: Total Renewals, Length: 423448, dtype: int64
# 0         5
# 1         5
# 2         5
# 3         5
# 4         5
#          ..
# 423443    5
# 423444    5
# 423445    5
# 423446    5
# 423447    5
# Name: Total Renewals, Length: 423448, dtype: int64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    5  20 to 24 years                P1
# 1                    5  25 to 34 years                S7
# ...

# %%
df = pd.read_csv("../data/Library_Usage.csv")

# %%
import numpy as np

df['is_adult'] = df['Patron Type Definition'] == 'ADULT'
df['log_renewals'] = np.log(df['Total Renewals'] + 1)
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df['Circulation Active Year'] = pd.to_numeric(
  df['Circulation Active Year'], errors='coerce'
)
#df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df['Circulation Active Month']= pd.to_datetime(
    df['Circulation Active Month'],
    errors='coerce',
    format="%B"
)

# %%
#df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df['Circulation Active Month']=df['Circulation Active Month'].dt.month
#df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df['Membership Duration'] = (df['Circulation Active Year'] - df['Year Patron Registered'])*12 + df['Circulation Active Month']

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
df['Membership Duration']=df['Membership Duration'].fillna(0)

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %% [markdown]
# # 2.6 Filtern

# %%
# Filtere den Datensatz nach Kindern unter 10 Jahren. Wie viele Einträge erhältst Du? 38242
row_filter1 = (df['Age Range'] == '0 to 9 years')
df.loc[row_filter1]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 287                    1               JUVENILE                0
# 289                    1               JUVENILE               20
# 291                    1               JUVENILE               53
# 292                    1               JUVENILE                1
# 295                    1               JUVENILE                0
# ...                  ...                    ...              ...
# 423434                 1               JUVENILE               10
# 423437                 1               JUVENILE                0
# 423439                 1               JUVENILE                0
# 423445                 5                  STAFF              208
# 423447                 1               JUVENILE                0
#
#         Total Renewals     Age Range Home Library Code  \
# 287                  0  0 to 9 years                M6
# 289                  0  0 to 9 years                E9
# ...

# %%
#Gibt es Personen mit mehr als 20000 Ausleihen?ja 3
filter1 = (df['Total Checkouts'] >= 20000)
filter1.unique()
df.loc[filter1]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 146615                 0                  ADULT            24093
# 163893                 3                 SENIOR            25223
# 293371                 0                  ADULT            35907
#
#         Total Renewals       Age Range Home Library Code  \
# 146615             383  45 to 54 years                 X
# 163893             448  65 to 74 years                 X
# 293371             116  35 to 44 years                V3
#
#        Home Library Definition  Circulation Active Month  \
# 146615            Main Library                       7.0
# 163893            Main Library                       7.0
# 293371       Visitacion Valley                       7.0
#
#         Circulation Active Year Notice Preference Code  \
# 146615                   2016.0                      p
# 163893                   2016.0                      p
# 293371                   2016.0                      p
#
# ...

# %%
df
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 0                      0                  ADULT                0
# 1                      0                  ADULT               31
# 2                      0                  ADULT                0
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# ...                  ...                    ...              ...
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
# 423447                 1               JUVENILE                0
#
#         Total Renewals       Age Range Home Library Code  \
# 0                    0  20 to 24 years                P1
# 1                   22  25 to 34 years                S7
# ...

# %%
#Wie viele Personen stammen aus dem Norden San Franciscos (Supervisor Districts 1, 2 und 3): 70091
# warum mit function Series.isin()? 
filter2 = (df['Supervisor District'] >= 1) & (df['Supervisor District'] <=3)
df.loc[filter2]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 3                      0                  ADULT                0
# 4                      0                  ADULT              126
# 13                     0                  ADULT               88
# 14                     0                  ADULT               22
# 17                     0                  ADULT                5
# ...                  ...                    ...              ...
# 423415                 1               JUVENILE              475
# 423418                 3                 SENIOR                6
# 423420                 1               JUVENILE                5
# 423427                 1               JUVENILE               42
# 423441                 3                 SENIOR             1812
#
#         Total Renewals          Age Range Home Library Code  \
# 3                    0     25 to 34 years                 X
# 4                   11     45 to 54 years                M2
# ...

# %%
#Wie viele Prozent der Beobachtungen haben eine Membership Duration von Null Monaten? 16.036%
total  = len(df)
filter4 = (df['Membership Duration'] == 0)
teil = len(df.loc[filter4])
percent = (teil/total)*100
print(percent)
# Out:
# 16.035971358938998

# %% [markdown]
# # 2.7 Datentypen & 2.8 Exkurs: Fehlende Werte (20 Min) &2.9
#
# 2.7 ->
# Was unterscheidet den Wert None vom Wert "None"? Was den Wert 5 vom Wert "5"? Was den Wert "NaN" vom Wert NaN? Ist True und "True" das gleiche?
#
# "None", "5", "NaN" "True" sind STRING Type
# NaN: Not a Number, 5: integer True: bool, None: NULL objects

# %%
#2.9
df.head(10)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 0                  ADULT                0               0
# 1                 0                  ADULT               31              22
# 2                 0                  ADULT                0               0
# 3                 0                  ADULT                0               0
# 4                 0                  ADULT              126              11
# 5                 3                 SENIOR                0               0
# 6                 0                  ADULT             3002            1689
# 7                 0                  ADULT                4               0
# 8                 0                  ADULT               20               0
# 9                 0                  ADULT                3               1
#
#         Age Range Home Library Code Home Library Definition  \
# 0  20 to 24 years                P1                    Park
# ...

# %%
# 2.8
df = pd.read_csv("../data/Library_Usage.csv")
print(df.isna().sum())
df_clean = df.dropna()
print(len(df_clean))
## Welche Spalten enthalten alles fehlende Werte?Age Range, Home Library Code, Supervisor District
print("entferne Daten Anzahl: ")
print(len(df) - len(df_clean))   #Wie viele Beobachtungen wurden dabei entfernt 110480 Datensätze
df_clean.to_csv('../data/Library_Usage_Clean.csv')
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          215
# Home Library Code                   40
# Home Library Definition              0
# Circulation Active Month             0
# Circulation Active Year              0
# Notice Preference Code               0
# Notice Preference Definition         0
# Provided Email Address               0
# Year Patron Registered               0
# Outside of County                    0
# Supervisor District             110310
# dtype: int64
# 312968
# entferne Daten Anzahl:
# 110480

# %%
df_na_values = pd.read_csv("../data/Library_Usage.csv", na_values="None")
df_na_values.isna().sum()
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          215
# Home Library Code                   40
# Home Library Definition              0
# Circulation Active Month         67904
# Circulation Active Year          67904
# Notice Preference Code               0
# Notice Preference Definition         0
# Provided Email Address               0
# Year Patron Registered               0
# Outside of County                    0
# Supervisor District             110310
# dtype: int64

# %%
df_clean2 = df_na_values.dropna()
df_clean2.to_csv('../data/Library_Usage_Clean_na_value_option.csv')
df_clean2
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 1                      0                  ADULT               31
# 4                      0                  ADULT              126
# 6                      0                  ADULT             3002
# 7                      0                  ADULT                4
# 8                      0                  ADULT               20
# ...                  ...                    ...              ...
# 423442                 2            YOUNG ADULT              608
# 423443                 0                  ADULT              291
# 423444                 0                  ADULT               15
# 423445                 5                  STAFF              208
# 423446                 0                  ADULT               26
#
#         Total Renewals       Age Range Home Library Code  \
# 1                   22  25 to 34 years                S7
# 4                   11  45 to 54 years                M2
# ...
